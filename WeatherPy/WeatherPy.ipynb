# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Included this additional cell to test 1 api call



# Set the API base URL
# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "metric"

# # Define an empty list to fetch the weather data for each city
# city_data = []

# # Print to logger
# print("Beginning Data Retrieval     ")
# print("-----------------------------")

# # Create counters
# record_count = 1
# set_count = 1

# Included this additional cell to test 1 api call

# city = "faya"
# city_url = f"{url}appid={weather_api_key}&units={units}&q="
# print (city_url)
# city_weather = requests.get(city_url + city).json()
# print(f"weather data for city: {city_weather}.") 

# city_lat = city_weather['coord']['lat']
# city_lng = city_weather['coord']['lon']
# city_max_temp = city_weather['main']['temp_max']
# city_humidity = city_weather['main']['humidity']
# city_clouds = city_weather['clouds']['all']
# city_wind = city_weather['wind']['speed']
# city_country = city_weather['sys']['country']
# city_date = city_weather['dt']

# #Append the City information into city_data list
# city_data.append({"City": city, 
#                 "Lat": city_lat, 
#                 "Lng": city_lng,
#                 "Max Temp": city_max_temp,
#                 "Humidity": city_humidity,
#                 "Cloudiness": city_clouds,
#                 "Wind Speed": city_wind,
#                 "Country": city_country,
#                 "Date": city_date})

# # create DataFrame
# city_data_df = pd.DataFrame(city_data)
# city_data_df.count()

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = (datetime.datetime.fromtimestamp(city_weather['dt'])).strftime('%m-%d-%Y')


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | weisswasser
# Processing Record 2 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 1 | nova sintra
# Processing Record 4 of Set 1 | fairborn
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | nagqu
# Processing Record 7 of Set 1 | funafuti
# Processing Record 8 of Set 1 | mejit
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | upington
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | kuta
# Processing Record 15 of Set 1 | invercargill
# Processing Record 16 of Set 1 | arno
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | olonkinbyen
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | terenozek
# Processing Record 21 of Set 1 | gamba
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | codrington
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | stanley
# Processing Record 26 of Set 1 | hawaiian paradise park
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | badger
# Processing Record 29 of Set 1 | papatowai
# Processing Record 30 of Set 1 | waitangi
# Processing Record 31 of Set 1 | nantucket
# Processing Record 32 of Set 1 | el calafate
# Processing Record 33 of Set 1 | newman
# Processing Record 34 of Set 1 | nemuro
# Processing Record 35 of Set 1 | prince rupert
# Processing Record 36 of Set 1 | al-`ula
# City not found. Skipping...
# Processing Record 37 of Set 1 | hafar al-batin
# Processing Record 38 of Set 1 | st. john's
# Processing Record 39 of Set 1 | loukhi
# Processing Record 40 of Set 1 | santiago citendeje
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | whitehorse
# Processing Record 43 of Set 1 | labytnangi
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | margaret river
# Processing Record 46 of Set 1 | mitu
# Processing Record 47 of Set 1 | dong ha
# Processing Record 48 of Set 1 | chinchani
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | aroma
# Processing Record 0 of Set 2 | praia da vitoria
# Processing Record 1 of Set 2 | utrik
# Processing Record 2 of Set 2 | akureyri
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | west island
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | kitui
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | hereford
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | haiku-pauwela
# Processing Record 11 of Set 2 | bad belzig
# Processing Record 12 of Set 2 | tidjikja
# Processing Record 13 of Set 2 | qaqortoq
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | borba
# Processing Record 16 of Set 2 | elazig
# Processing Record 17 of Set 2 | dudinka
# Processing Record 18 of Set 2 | wenzhou
# Processing Record 19 of Set 2 | howrah
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | blackmans bay
# Processing Record 22 of Set 2 | yarmouth
# Processing Record 23 of Set 2 | manokwari
# Processing Record 24 of Set 2 | pangody
# Processing Record 25 of Set 2 | haradok
# Processing Record 26 of Set 2 | vorgashor
# Processing Record 27 of Set 2 | reyes
# Processing Record 28 of Set 2 | boa vista
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | sajir
# Processing Record 31 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 32 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 2 | belmonte
# Processing Record 34 of Set 2 | fort bragg
# Processing Record 35 of Set 2 | al jawf
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | iskateley
# Processing Record 38 of Set 2 | trincomalee
# Processing Record 39 of Set 2 | atafu village
# Processing Record 40 of Set 2 | patterson
# Processing Record 41 of Set 2 | kapa'a
# Processing Record 42 of Set 2 | swainsboro
# Processing Record 43 of Set 2 | tsiombe
# Processing Record 44 of Set 2 | ghat
# Processing Record 45 of Set 2 | ust-nera
# Processing Record 46 of Set 2 | anadyr
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | jinchang
# Processing Record 0 of Set 3 | stornoway
# Processing Record 1 of Set 3 | aral
# Processing Record 2 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 3 of Set 3 | ketchikan
# Processing Record 4 of Set 3 | le port
# Processing Record 5 of Set 3 | itupiranga
# Processing Record 6 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 7 of Set 3 | choibalsan
# Processing Record 8 of Set 3 | yelizovo
# Processing Record 9 of Set 3 | plouzane
# Processing Record 10 of Set 3 | polyarnyy
# Processing Record 11 of Set 3 | hirara
# Processing Record 12 of Set 3 | buala
# Processing Record 13 of Set 3 | hotan
# Processing Record 14 of Set 3 | xingcheng
# Processing Record 15 of Set 3 | paso de los libres
# Processing Record 16 of Set 3 | ta`u
# Processing Record 17 of Set 3 | privolzhsk
# Processing Record 18 of Set 3 | kralendijk
# Processing Record 19 of Set 3 | panaba
# Processing Record 20 of Set 3 | gulf shores
# Processing Record 21 of Set 3 | opuwo
# Processing Record 22 of Set 3 | kailua-kona
# Processing Record 23 of Set 3 | rundu
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | susuman
# Processing Record 27 of Set 3 | la ronge
# Processing Record 28 of Set 3 | port mathurin
# Processing Record 29 of Set 3 | sinabang
# Processing Record 30 of Set 3 | mocimboa
# Processing Record 31 of Set 3 | mountain home
# Processing Record 32 of Set 3 | kubinka
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | college
# Processing Record 35 of Set 3 | suomussalmi
# Processing Record 36 of Set 3 | gadzhiyevo
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | gonaives
# Processing Record 39 of Set 3 | masuguru
# Processing Record 40 of Set 3 | selty
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | itoman
# Processing Record 44 of Set 3 | port saint john's
# Processing Record 45 of Set 3 | mahavelona
# Processing Record 46 of Set 3 | bol
# Processing Record 47 of Set 3 | pahrump
# Processing Record 48 of Set 3 | finspang
# Processing Record 49 of Set 3 | chos malal
# Processing Record 0 of Set 4 | salalah
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | mermoz boabab
# Processing Record 3 of Set 4 | meadow lakes
# Processing Record 4 of Set 4 | olinda
# Processing Record 5 of Set 4 | yatou
# Processing Record 6 of Set 4 | rio gallegos
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | vilyuchinsk
# Processing Record 9 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 10 of Set 4 | shumikha
# Processing Record 11 of Set 4 | daru
# Processing Record 12 of Set 4 | copala
# Processing Record 13 of Set 4 | ar ruways
# Processing Record 14 of Set 4 | sinop
# Processing Record 15 of Set 4 | rio grande
# Processing Record 16 of Set 4 | sudislavl'
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | laminusa
# Processing Record 19 of Set 4 | hadibu
# Processing Record 20 of Set 4 | aoulef
# Processing Record 21 of Set 4 | ilabaya
# Processing Record 22 of Set 4 | huicheng
# Processing Record 23 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 24 of Set 4 | mili
# Processing Record 25 of Set 4 | keflavik
# Processing Record 26 of Set 4 | glenwood springs
# Processing Record 27 of Set 4 | udachny
# Processing Record 28 of Set 4 | tual
# Processing Record 29 of Set 4 | bantogon
# Processing Record 30 of Set 4 | pingxiang
# Processing Record 31 of Set 4 | igrim
# Processing Record 32 of Set 4 | balachor
# Processing Record 33 of Set 4 | wailua homesteads
# Processing Record 34 of Set 4 | dadukou
# Processing Record 35 of Set 4 | sandnessjoen
# Processing Record 36 of Set 4 | independence
# Processing Record 37 of Set 4 | nowogrod bobrzanski
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | skelleftea
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | kharod
# Processing Record 42 of Set 4 | saint-pierre
# Processing Record 43 of Set 4 | gebeit
# Processing Record 44 of Set 4 | okhotsk
# Processing Record 45 of Set 4 | constantia
# Processing Record 46 of Set 4 | ambon
# Processing Record 47 of Set 4 | smarhon
# Processing Record 48 of Set 4 | klyuchi
# Processing Record 49 of Set 4 | windhoek
# Processing Record 0 of Set 5 | xilin hot
# Processing Record 1 of Set 5 | huarmey
# Processing Record 2 of Set 5 | san matias
# Processing Record 3 of Set 5 | flin flon
# Processing Record 4 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 5 | aden
# Processing Record 6 of Set 5 | bakanas
# Processing Record 7 of Set 5 | kone
# Processing Record 8 of Set 5 | magadan
# Processing Record 9 of Set 5 | chongwe
# Processing Record 10 of Set 5 | nizhneudinsk
# Processing Record 11 of Set 5 | kerch
# Processing Record 12 of Set 5 | arar
# Processing Record 13 of Set 5 | ende
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | richards bay
# Processing Record 17 of Set 5 | kwakoa
# Processing Record 18 of Set 5 | kodiak
# Processing Record 19 of Set 5 | international falls
# Processing Record 20 of Set 5 | morondava
# Processing Record 21 of Set 5 | bei'an
# Processing Record 22 of Set 5 | sao paulo de olivenca
# Processing Record 23 of Set 5 | la passe
# Processing Record 24 of Set 5 | isafjordur
# Processing Record 25 of Set 5 | vilyuysk
# Processing Record 26 of Set 5 | tyukhtet
# Processing Record 27 of Set 5 | raychikhinsk
# Processing Record 28 of Set 5 | sakaiminato
# Processing Record 29 of Set 5 | awjilah
# Processing Record 30 of Set 5 | methil
# Processing Record 31 of Set 5 | samokov
# Processing Record 32 of Set 5 | qamdo
# Processing Record 33 of Set 5 | navlya
# Processing Record 34 of Set 5 | roja
# Processing Record 35 of Set 5 | cocachacra
# Processing Record 36 of Set 5 | jayapura
# Processing Record 37 of Set 5 | cortez
# Processing Record 38 of Set 5 | port alfred
# Processing Record 39 of Set 5 | zheleznogorsk-ilimskiy
# Processing Record 40 of Set 5 | xiaoweizhai
# Processing Record 41 of Set 5 | palmer
# Processing Record 42 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | ghanzi
# Processing Record 45 of Set 5 | saipan
# Processing Record 46 of Set 5 | lembar
# City not found. Skipping...
# Processing Record 47 of Set 5 | mugia
# Processing Record 48 of Set 5 | ingeniero jacobacci
# Processing Record 49 of Set 5 | rabo de peixe
# Processing Record 0 of Set 6 | nuuk
# Processing Record 1 of Set 6 | chonchi
# Processing Record 2 of Set 6 | chiili
# City not found. Skipping...
# Processing Record 3 of Set 6 | georgetown
# Processing Record 4 of Set 6 | dawei
# Processing Record 5 of Set 6 | grand falls-windsor
# Processing Record 6 of Set 6 | hoemul-li
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | kupang
# Processing Record 9 of Set 6 | tura
# Processing Record 10 of Set 6 | kiunga
# Processing Record 11 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 12 of Set 6 | coron
# Processing Record 13 of Set 6 | fale old settlement
# Processing Record 14 of Set 6 | taro
# Processing Record 15 of Set 6 | kidal
# Processing Record 16 of Set 6 | dzerzhinskoye
# Processing Record 17 of Set 6 | kingston
# Processing Record 18 of Set 6 | nuku'alofa
# Processing Record 19 of Set 6 | ljungby
# Processing Record 20 of Set 6 | tvoroyri
# Processing Record 21 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 22 of Set 6 | yoro
# Processing Record 23 of Set 6 | labruguiere
# Processing Record 24 of Set 6 | kuznetsk
# Processing Record 25 of Set 6 | bahia de kino
# Processing Record 26 of Set 6 | yerofey pavlovich
# Processing Record 27 of Set 6 | farafangana
# Processing Record 28 of Set 6 | yoloten
# Processing Record 29 of Set 6 | arvayheer
# Processing Record 30 of Set 6 | al jubayl
# Processing Record 31 of Set 6 | kavaratti
# Processing Record 32 of Set 6 | gwio kura
# Processing Record 33 of Set 6 | rongelap
# Processing Record 34 of Set 6 | tucuma
# Processing Record 35 of Set 6 | camabatela
# Processing Record 36 of Set 6 | tagiura
# Processing Record 37 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 6 | flying fish cove
# Processing Record 39 of Set 6 | cabedelo
# Processing Record 40 of Set 6 | fortuna
# Processing Record 41 of Set 6 | kalmunai
# Processing Record 42 of Set 6 | koz'modem'yansk
# Processing Record 43 of Set 6 | howard springs
# Processing Record 44 of Set 6 | lerwick
# Processing Record 45 of Set 6 | holualoa
# Processing Record 46 of Set 6 | lulea
# Processing Record 47 of Set 6 | cidade velha
# Processing Record 48 of Set 6 | yenotayevka
# Processing Record 49 of Set 6 | nikolayevsk-on-amure
# Processing Record 0 of Set 7 | sitka
# Processing Record 1 of Set 7 | enewetak
# Processing Record 2 of Set 7 | afaahiti
# Processing Record 3 of Set 7 | singkil
# Processing Record 4 of Set 7 | hoxtolgay
# City not found. Skipping...
# Processing Record 5 of Set 7 | tacna
# Processing Record 6 of Set 7 | don luan
# Processing Record 7 of Set 7 | boquete
# Processing Record 8 of Set 7 | sambava
# Processing Record 9 of Set 7 | colonia
# Processing Record 10 of Set 7 | buka
# Processing Record 11 of Set 7 | basco
# Processing Record 12 of Set 7 | talanga
# Processing Record 13 of Set 7 | gorom-gorom
# Processing Record 14 of Set 7 | poltavka
# Processing Record 15 of Set 7 | safaga
# Processing Record 16 of Set 7 | weligama
# Processing Record 17 of Set 7 | almeirim
# Processing Record 18 of Set 7 | sisimiut
# Processing Record 19 of Set 7 | strezhevoy
# Processing Record 20 of Set 7 | buckhannon
# Processing Record 21 of Set 7 | smithers
# Processing Record 22 of Set 7 | tazovsky
# Processing Record 23 of Set 7 | nar'yan-mar
# Processing Record 24 of Set 7 | carnarvon
# Processing Record 25 of Set 7 | sinazongwe
# Processing Record 26 of Set 7 | kudahuvadhoo
# Processing Record 27 of Set 7 | san antonio de pale
# Processing Record 28 of Set 7 | tobol'sk
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | rawatsar
# Processing Record 31 of Set 7 | eldorado
# Processing Record 32 of Set 7 | smach mean chey
# City not found. Skipping...
# Processing Record 33 of Set 7 | tolanaro
# Processing Record 34 of Set 7 | shanhaiguan
# Processing Record 35 of Set 7 | ad dawadimi
# Processing Record 36 of Set 7 | senillosa
# Processing Record 37 of Set 7 | nova vicosa
# Processing Record 38 of Set 7 | mahina
# Processing Record 39 of Set 7 | uturoa
# Processing Record 40 of Set 7 | al lagowa
# Processing Record 41 of Set 7 | ewo
# Processing Record 42 of Set 7 | rabaul
# Processing Record 43 of Set 7 | zyryanovsk
# Processing Record 44 of Set 7 | puerto santa
# Processing Record 45 of Set 7 | ciudad sabinas hidalgo
# Processing Record 46 of Set 7 | zorritos
# Processing Record 47 of Set 7 | mumbwa
# Processing Record 48 of Set 7 | andergrove
# Processing Record 49 of Set 7 | laojunmiao
# Processing Record 0 of Set 8 | cozumel
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | remire-montjoly
# Processing Record 3 of Set 8 | berdigestyakh
# Processing Record 4 of Set 8 | gagliano del capo
# Processing Record 5 of Set 8 | san ignacio rio muerto
# Processing Record 6 of Set 8 | ambodivoara
# City not found. Skipping...
# Processing Record 7 of Set 8 | lycksele
# Processing Record 8 of Set 8 | kangding
# Processing Record 9 of Set 8 | as sulayyil
# Processing Record 10 of Set 8 | frankfort
# Processing Record 11 of Set 8 | eraan
# Processing Record 12 of Set 8 | kondopoga
# Processing Record 13 of Set 8 | summerland
# Processing Record 14 of Set 8 | gisborne
# Processing Record 15 of Set 8 | xai-xai
# Processing Record 16 of Set 8 | severo-yeniseyskiy
# Processing Record 17 of Set 8 | lourical
# Processing Record 18 of Set 8 | torbat-e jam
# Processing Record 19 of Set 8 | santana
# Processing Record 20 of Set 8 | puerto armuelles
# Processing Record 21 of Set 8 | baki
# Processing Record 22 of Set 8 | minas de marcona
# Processing Record 23 of Set 8 | hluti
# Processing Record 24 of Set 8 | zhanibek
# Processing Record 25 of Set 8 | bermeo
# Processing Record 26 of Set 8 | ancud
# Processing Record 27 of Set 8 | ta'izz
# Processing Record 28 of Set 8 | kirakira
# Processing Record 29 of Set 8 | valle hermoso
# Processing Record 30 of Set 8 | lata
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | kalemie
# Processing Record 33 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 8 | bang saphan
# Processing Record 35 of Set 8 | weno
# Processing Record 36 of Set 8 | tainan
# Processing Record 37 of Set 8 | bardsir
# Processing Record 38 of Set 8 | antofagasta
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | oranjemund
# Processing Record 41 of Set 8 | cooper's town
# Processing Record 42 of Set 8 | mount pearl
# Processing Record 43 of Set 8 | mumbai
# Processing Record 44 of Set 8 | manchester
# Processing Record 45 of Set 8 | baker city
# Processing Record 46 of Set 8 | freetown
# Processing Record 47 of Set 8 | urangan
# Processing Record 48 of Set 8 | launceston
# Processing Record 49 of Set 8 | porto-vecchio
# Processing Record 0 of Set 9 | labrador city
# Processing Record 1 of Set 9 | mandan
# Processing Record 2 of Set 9 | esmeralda
# Processing Record 3 of Set 9 | wajir
# Processing Record 4 of Set 9 | aasiaat
# Processing Record 5 of Set 9 | xinzhi
# Processing Record 6 of Set 9 | ponta delgada
# Processing Record 7 of Set 9 | yanbu
# Processing Record 8 of Set 9 | murzuq
# Processing Record 9 of Set 9 | mhamid
# Processing Record 10 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 9 | nogliki
# Processing Record 12 of Set 9 | kavieng
# Processing Record 13 of Set 9 | kayangel
# Processing Record 14 of Set 9 | la'ie
# Processing Record 15 of Set 9 | tofol
# Processing Record 16 of Set 9 | sao vicente
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | arraias
# Processing Record 19 of Set 9 | wanxian
# Processing Record 20 of Set 9 | el nido
# Processing Record 21 of Set 9 | burang
# Processing Record 22 of Set 9 | mount gambier
# Processing Record 23 of Set 9 | san pedro
# Processing Record 24 of Set 9 | cill airne
# Processing Record 25 of Set 9 | mawlamyinegyunn
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | leitchfield
# Processing Record 29 of Set 9 | erbiceni
# Processing Record 30 of Set 9 | atherton
# Processing Record 31 of Set 9 | najran
# Processing Record 32 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 9 | gambela
# Processing Record 34 of Set 9 | kagal'nitskaya
# Processing Record 35 of Set 9 | tutoia
# Processing Record 36 of Set 9 | hovd
# Processing Record 37 of Set 9 | bikenibeu village
# Processing Record 38 of Set 9 | mingora
# Processing Record 39 of Set 9 | kirensk
# Processing Record 40 of Set 9 | tongouson
# Processing Record 41 of Set 9 | paphos
# Processing Record 42 of Set 9 | broken hill
# Processing Record 43 of Set 9 | hilo
# Processing Record 44 of Set 9 | nadi
# Processing Record 45 of Set 9 | mammoth lakes
# Processing Record 46 of Set 9 | san patricio
# Processing Record 47 of Set 9 | anori
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | portland
# Processing Record 0 of Set 10 | smara
# Processing Record 1 of Set 10 | sao joao da barra
# Processing Record 2 of Set 10 | al bayda
# Processing Record 3 of Set 10 | harrisburg
# Processing Record 4 of Set 10 | pisco
# Processing Record 5 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 6 of Set 10 | altai
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | bereeda
# Processing Record 10 of Set 10 | saint-joseph
# Processing Record 11 of Set 10 | karukh
# Processing Record 12 of Set 10 | new norfolk
# Processing Record 13 of Set 10 | hobyo
# Processing Record 14 of Set 10 | malvan
# Processing Record 15 of Set 10 | ovalle
# Processing Record 16 of Set 10 | paita
# Processing Record 17 of Set 10 | alo
# Processing Record 18 of Set 10 | dzhambeyty
# Processing Record 19 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 10 | masterton
# Processing Record 21 of Set 10 | christchurch
# Processing Record 22 of Set 10 | birjand
# Processing Record 23 of Set 10 | coromandel
# Processing Record 24 of Set 10 | hirado
# Processing Record 25 of Set 10 | ust-tsilma
# Processing Record 26 of Set 10 | boyolangu
# Processing Record 27 of Set 10 | antsiranana
# Processing Record 28 of Set 10 | batibo
# Processing Record 29 of Set 10 | goz beida
# Processing Record 30 of Set 10 | anar darah
# Processing Record 31 of Set 10 | auki
# Processing Record 32 of Set 10 | juan griego
# Processing Record 33 of Set 10 | saint marys
# Processing Record 34 of Set 10 | okahao
# Processing Record 35 of Set 10 | kapuskasing
# Processing Record 36 of Set 10 | muncar
# Processing Record 37 of Set 10 | guerrero negro
# Processing Record 38 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 39 of Set 10 | homer
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | ghadamis
# Processing Record 42 of Set 10 | mathis
# Processing Record 43 of Set 10 | trstenik
# Processing Record 44 of Set 10 | jertih
# Processing Record 45 of Set 10 | moussoro
# Processing Record 46 of Set 10 | berezovyy
# Processing Record 47 of Set 10 | harwich
# Processing Record 48 of Set 10 | trondheim
# Processing Record 49 of Set 10 | bangassou
# Processing Record 0 of Set 11 | lashio
# Processing Record 1 of Set 11 | magdalena contreras
# Processing Record 2 of Set 11 | soio
# Processing Record 3 of Set 11 | tchintabaraden
# Processing Record 4 of Set 11 | nadym
# Processing Record 5 of Set 11 | sikasso
# Processing Record 6 of Set 11 | villa gesell
# Processing Record 7 of Set 11 | nizhnyaya tavda
# Processing Record 8 of Set 11 | borgarnes
# Processing Record 9 of Set 11 | queenstown
# Processing Record 10 of Set 11 | chapaev
# Processing Record 11 of Set 11 | taiynsha
# Processing Record 12 of Set 11 | pitimbu
# Processing Record 13 of Set 11 | kas
# Processing Record 14 of Set 11 | egilsstadir
# Processing Record 15 of Set 11 | rikaze
# Processing Record 16 of Set 11 | lusambo
# Processing Record 17 of Set 11 | gizo
# Processing Record 18 of Set 11 | nurota
# Processing Record 19 of Set 11 | meulaboh
# Processing Record 20 of Set 11 | anka
# Processing Record 21 of Set 11 | kurmuk
# Processing Record 22 of Set 11 | usogorsk
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | vilhena
# Processing Record 25 of Set 11 | mawlaik
# Processing Record 26 of Set 11 | isangel
# Processing Record 27 of Set 11 | igarka
# Processing Record 28 of Set 11 | north bend
# Processing Record 29 of Set 11 | birobidzhan
# Processing Record 30 of Set 11 | heroica caborca
# Processing Record 31 of Set 11 | svetlyy
# Processing Record 32 of Set 11 | labuan
# Processing Record 33 of Set 11 | vegreville
# Processing Record 34 of Set 11 | narimanov
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | mount isa
# Processing Record 37 of Set 11 | prince albert
# Processing Record 38 of Set 11 | gorgoram
# Processing Record 39 of Set 11 | muntok
# Processing Record 40 of Set 11 | leua
# Processing Record 41 of Set 11 | alice springs
# Processing Record 42 of Set 11 | backi petrovac
# Processing Record 43 of Set 11 | turpan
# Processing Record 44 of Set 11 | hull
# Processing Record 45 of Set 11 | barcelos
# Processing Record 46 of Set 11 | cruzeiro do sul
# Processing Record 47 of Set 11 | kenora
# Processing Record 48 of Set 11 | dame-marie
# Processing Record 49 of Set 11 | nkhata bay
# Processing Record 0 of Set 12 | pyhajarvi
# Processing Record 1 of Set 12 | brookings
# Processing Record 2 of Set 12 | suluktu
# Processing Record 3 of Set 12 | bagli
# Processing Record 4 of Set 12 | chegdomyn
# Processing Record 5 of Set 12 | tukrah
# Processing Record 6 of Set 12 | katsuren-haebaru
# Processing Record 7 of Set 12 | trang
# Processing Record 8 of Set 12 | otacilio costa
# Processing Record 9 of Set 12 | sirte
# Processing Record 10 of Set 12 | severo-vostotchnyi bank
# Processing Record 11 of Set 12 | puerto deseado
# Processing Record 12 of Set 12 | tomatlan
# Processing Record 13 of Set 12 | paramonga
# Processing Record 14 of Set 12 | seosan
# Processing Record 15 of Set 12 | lyantor
# Processing Record 16 of Set 12 | papao
# Processing Record 17 of Set 12 | kirkwall
# Processing Record 18 of Set 12 | gazojak
# Processing Record 19 of Set 12 | wuhai
# Processing Record 20 of Set 12 | longonjo
# Processing Record 21 of Set 12 | sorong
# Processing Record 22 of Set 12 | volnovakha
# Processing Record 23 of Set 12 | skovorodino
# Processing Record 24 of Set 12 | shahrak
# Processing Record 25 of Set 12 | wickenburg
# Processing Record 26 of Set 12 | gorgan
# Processing Record 27 of Set 12 | sangueya
# Processing Record 28 of Set 12 | jiagedaqi
# Processing Record 29 of Set 12 | palikir - national government center
# Processing Record 30 of Set 12 | sudzha
# Processing Record 31 of Set 12 | zaozersk
# Processing Record 32 of Set 12 | trujillo
# Processing Record 33 of Set 12 | ponneri
# Processing Record 34 of Set 12 | alice
# Processing Record 35 of Set 12 | lima
# Processing Record 36 of Set 12 | xining
# Processing Record 37 of Set 12 | conceicao do araguaia
# Processing Record 38 of Set 12 | chernyshevskiy
# Processing Record 39 of Set 12 | cartagena
# Processing Record 40 of Set 12 | novodvinsk
# Processing Record 41 of Set 12 | tocopilla
# Processing Record 42 of Set 12 | katsuura
# Processing Record 43 of Set 12 | muynoq
# Processing Record 44 of Set 12 | dunedin
# Processing Record 45 of Set 12 | damongo
# City not found. Skipping...
# Processing Record 46 of Set 12 | pont rouge
# Processing Record 47 of Set 12 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 48 of Set 12 | kununurra
# Processing Record 49 of Set 12 | sabang
# Processing Record 0 of Set 13 | pandan
# Processing Record 1 of Set 13 | lospalos
# Processing Record 2 of Set 13 | stenungsund
# Processing Record 3 of Set 13 | lihue
# Processing Record 4 of Set 13 | mil'kovo
# Processing Record 5 of Set 13 | xam nua
# Processing Record 6 of Set 13 | borgo val di taro
# Processing Record 7 of Set 13 | iwon-up
# Processing Record 8 of Set 13 | ceeldheer
# Processing Record 9 of Set 13 | turbat
# Processing Record 10 of Set 13 | saratamata
# City not found. Skipping...
# Processing Record 11 of Set 13 | s'arenal
# Processing Record 12 of Set 13 | ouezzane
# Processing Record 13 of Set 13 | murud
# Processing Record 14 of Set 13 | humberto de campos
# Processing Record 15 of Set 13 | nha trang
# Processing Record 16 of Set 13 | yanam
# Processing Record 17 of Set 13 | kismayo
# Processing Record 18 of Set 13 | nizhnesortymskiy
# Processing Record 19 of Set 13 | niort
# Processing Record 20 of Set 13 | fiambala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          595
# Lat           595
# Lng           595
# Max Temp      595
# Humidity      595
# Cloudiness    595
# Wind Speed    595
# Country       595
# Date          595
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   weisswasser  51.5167  14.6333      5.88        72          71        3.84
# 1   nova sintra  14.8667 -24.7167     21.92        66          99        5.51
# 2      fairborn  39.8209 -84.0194      3.36        74          75       11.32
# 3  puerto ayora  -0.7393 -90.3518     28.98        91          80        2.68
# 4         nagqu  31.5000  92.0000    -22.78        80           0        1.37
#
#   Country        Date
# 0      DE  12-18-2023
# 1      CV  12-18-2023
# 2      US  12-18-2023
# 3      EC  12-18-2023
# 4      CN  12-18-2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         weisswasser  51.5167  14.6333      5.88        72          71
# 1         nova sintra  14.8667 -24.7167     21.92        66          99
# 2            fairborn  39.8209 -84.0194      3.36        74          75
# 3        puerto ayora  -0.7393 -90.3518     28.98        91          80
# 4               nagqu  31.5000  92.0000    -22.78        80           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.84      DE  12-18-2023
# 1              5.51      CV  12-18-2023
# 2             11.32      US  12-18-2023
# 3              2.68      EC  12-18-2023
# 4              1.37      CN  12-18-2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x= 'Lat', y= 'Max Temp')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Latitude vs Temperature')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x= 'Lat', y= 'Humidity')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Max Latitude vs Humidity')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x= 'Lat', y= 'Cloudiness')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Max Latitude vs Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x= 'Lat', y= 'Wind Speed')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs Wind Speed')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
